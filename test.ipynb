# %%
import torch
from transformers import AutoTokenizer, AutoModel
from recovlm.models.intern_vl_3 import InternVLChatModel
from recovlm.training.common import set_default_dtype
from recovlm.data.dataloaders_v2 import get_dataloader
from torch.utils.data import DataLoader


import itertools

path = "/llm_reco/penghao03/intern-vl/InternVL3-2B"

# debug dataloader
dataset_config='examples/vlm/configs/debug7b_fsdp_3p_intern_vl.json'
with open(dataset_config, encoding="utf-8") as f:
    dataset_config = json.loads(f.read())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 4
#       2 from transformers import AutoTokenizer, AutoModel
#       3 from recovlm.models.intern_vl_3 import InternVLChatModel
# ----> 4 from recovlm.training.common import set_default_dtype
#       5 from recovlm.data.dataloaders_v2 import get_dataloader
#       6 from torch.utils.data import DataLoader
#
# File /llm_reco/penghao03/intern-vl/recovlm/recovlm/training/__init__.py:1
# ----> 1 from .checkpoint import load_safetensors, load_zero3_state_dict
#       3 __all__ = [
#       4     "load_safetensors",
#       5     "load_zero3_state_dict"
#       6 ]
#
# File /llm_reco/penghao03/intern-vl/recovlm/recovlm/training/checkpoint.py:13
#      11 from safetensors import safe_open
#      12 import torch.distributed as dist
# ---> 13 import deepspeed
#      14 from concurrent.futures import Future
#      16 from recovlm.training.distributed import get_world_size_and_rank
#
# File /usr/local/lib/python3.10/dist-packages/deepspeed/__init__.py:25
#      22 else:
#      23     HAS_TRITON = False
# ---> 25 from . import ops
#      26 from . import module_inject
#      28 from .accelerator import get_accelerator
#
# File /usr/local/lib/python3.10/dist-packages/deepspeed/ops/__init__.py:11
#       9 from . import lion
#      10 from . import sparse_attention
# ---> 11 from . import transformer
#      12 from . import fp_quantizer
#      13 from .transformer import DeepSpeedTransformerLayer, DeepSpeedTransformerConfig
#
# File /usr/local/lib/python3.10/dist-packages/deepspeed/ops/transformer/__init__.py:8
#       6 from .transformer import DeepSpeedTransformerLayer, DeepSpeedTransformerConfig
#       7 from .inference.config import DeepSpeedInferenceConfig
# ----> 8 from ...model_implementations.transformers.ds_transformer import DeepSpeedTransformerInference
#       9 from .inference.moe_inference import DeepSpeedMoEInferenceConfig, DeepSpeedMoEInference
#
# File /usr/local/lib/python3.10/dist-packages/deepspeed/model_implementations/transformers/ds_transformer.py:18
#      16 import deepspeed
#      17 if deepspeed.HAS_TRITON:
# ---> 18     from deepspeed.ops.transformer.inference.triton.mlp import TritonMLP
#      19     from deepspeed.ops.transformer.inference.triton.attention import TritonSelfAttention
#      22 class DeepSpeedTransformerInference(nn.Module):
#
# File /usr/local/lib/python3.10/dist-packages/deepspeed/ops/transformer/inference/__init__.py:7
#       1 # Copyright (c) Microsoft Corporation.
#       2 # SPDX-License-Identifier: Apache-2.0
#       3
#       4 # DeepSpeed Team
#       6 from .config import DeepSpeedInferenceConfig
# ----> 7 from ....model_implementations.transformers.ds_transformer import DeepSpeedTransformerInference
#       8 from .moe_inference import DeepSpeedMoEInferenceConfig, DeepSpeedMoEInference
#
# ImportError: cannot import name 'DeepSpeedTransformerInference' from partially initialized module 'deepspeed.model_implementations.transformers.ds_transformer' (most likely due to a circular import) (/usr/local/lib/python3.10/dist-packages/deepspeed/model_implementations/transformers/ds_transformer.py)
